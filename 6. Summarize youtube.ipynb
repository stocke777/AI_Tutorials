# %%
import os
from dotenv import load_dotenv
from openai import OpenAI

# %%
load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

# Check the key

if not api_key:
    print("No API key was found!")
elif not api_key.startswith("sk-proj-"):
    print("An API key was found, but it doesn't start sk-proj-;")
elif api_key.strip() != api_key:
    print("An API key was found, but it looks like it might have space or tab characters at the start or end")
else:
    print("API key found and looks good so far!")
# Out:
# API key found and looks good so far!

# %%
# This code grabs the auto-generated subtitles, strips out the timestamps, and gives you plain text.
import yt_dlp
import glob
import re

def get_youtube_transcript(url):
    # Create a temporary output directory
    output_dir = "yt_subs"
    os.makedirs(output_dir, exist_ok=True)

    ydl_opts = {
        'skip_download': True,
        'writesubtitles': True,
        'writeautomaticsub': True,
        'subtitlesformat': 'vtt',
        'outtmpl': f'{output_dir}/%(id)s.%(ext)s',
        'quiet': True
    }

    with yt_dlp.YoutubeDL(ydl_opts) as ydl:
        info = ydl.extract_info(url, download=True)
        video_id = info.get("id")

    # Find the .vtt file
    vtt_files = glob.glob(f"{output_dir}/{video_id}*.vtt")
    if not vtt_files:
        raise FileNotFoundError("No .vtt subtitle file found. The video may not have captions.")

    with open(vtt_files[0], 'r', encoding='utf-8') as f:
        vtt = f.read()

    # Remove timestamps
    cleaned = re.sub(r"\d+:\d+\.\d+ --> \d+:\d+\.\d+.*\n?", '', vtt)
    return cleaned.strip()

# %%
# newspaper3k is pretty good at finding the actual content of a webpage

from newspaper import Article

def extract_article(url):
    article = Article(url)
    article.download()
    article.parse()
    return article.text

# %%
openai = OpenAI()
def summarize_text(text):
    prompt = f"Summarize this:\n\n{text}\n\nSummary:"
    response = openai.chat.completions.create(
        model="gpt-4o-mini",
        messages=[{"role": "user", "content": prompt}],
        max_tokens=300
    )
    return response.choices[0].message.content.strip()

# %%
yt_text = get_youtube_transcript("https://www.youtube.com/watch?v=M9x_koRZ2bA")
print(yt_text)
print(summarize_text(yt_text))
# Out:
# WARNING: ffmpeg not found. The downloaded format may not be the best available. Installing ffmpeg is strongly recommended: https://github.com/yt-dlp/yt-dlp#dependencies
# WEBVTT
# Kind: captions
# Language: en
#
# 00:00:00.000 --> 00:00:02.500
# Narrator:
# "Dark Souls had a story," you ask?
#
# 00:00:02.500 --> 00:00:07.000
# Indeed! Perhaps if your vision was not obfuscated by myriad deaths...
#
# 00:00:07.000 --> 00:00:08.700
# ...you might see more clearly!
#
# 00:00:08.800 --> 00:00:11.300
# Fret not, my crestfallen children...
#
# 00:00:11.300 --> 00:00:14.000
# ...for I shall reveal this to you!"
#
# 00:00:15.000 --> 00:00:18.000
# Dragon 1: "Bein' a dragon is... amazing!"
#
# 00:00:18.000 --> 00:00:20.000
# Dragon 2: "Amazing! Amaaaazzziiinnggg!"
#
# 00:00:20.000 --> 00:00:23.700
# Dragon 1: "Rulin' over our endless gray landscape
# of gray water and gray trees...
#
# 00:00:23.700 --> 00:00:25.300
# Dragon 1: "We even got this skull!"
#
# 00:00:25.300 --> 00:00:27.100
# Dragon 1: "The hell if I know where it came from."
#
# 00:00:27.100 --> 00:00:29.500
# Dragon 1: "This really is... the high life."
#
# 00:00:29.500 --> 00:00:31.400
# Dragon 3: "Except for Seath!
#
# 00:00:31.400 --> 00:00:34.400
# Dragon 1: "Aww, Seath! What's the matter, Seath?"
#
# 00:00:34.400 --> 00:00:39.000
# Dragon 1: "Still mad 'cause you're gonna die one day,
# 'cause you ain't got no scales?"
#
# 00:00:39.000 --> 00:00:40.400
# Dragon 2: "Bitch ain't got no legs."
#
# 00:00:40.400 --> 00:00:42.500
# Dragon 1: "Ain't even got legs!"
#
# 00:00:42.500 --> 00:00:46.000
# Dragon 2: "I even got this crystal shit that makes us
# Double Immortal, for some reason."
#
# 00:00:46.200 --> 00:00:47.200
# Dragon 2: "We don't even need it!"
#
# 00:00:47.200 --> 00:00:49.000
# Dragon 1: "Don't. Even. Need it!"
#
# 00:00:49.700 --> 00:00:51.700
# Dragon 3: "How's it feeeeeeel, Seath?"
#
# 00:00:51.700 --> 00:00:55.000
# Dragon 3: "...To be a ~bitch~?"
#
# 00:00:56.000 --> 00:00:57.500
# Lord Gwyn: "So you three found one, too?"
#
# 00:00:57.500 --> 00:01:00.000
# Lord Gwyn: "It's made me smarter! Stronger! More - "
#
# 00:01:02.800 --> 00:01:04.200
# Seath: "Lightning!"
#
# 00:01:05.500 --> 00:01:08.500
# Dragon 3: "Oh no! Lightning! Our one weakness!"
#
# 00:01:08.500 --> 00:01:11.500
# Dragon 1: "1.05 patch, save us!"
#
# 00:01:11.500 --> 00:01:15.000
# Dragon 2: "Argh! I've got miasma up my asshole!"
#
# 00:01:16.800 --> 00:01:19.700
# Lord Gwyn: "Seath, you betrayed SO good, here a castle."
#
# 00:01:19.700 --> 00:01:21.200
# Lord Gwyn: "Also, you a Duke."
#
# 00:01:21.200 --> 00:01:24.700
# Seath: "Excellent. Gonna go research some shit. Maybe go crazy."
#
# 00:01:24.700 --> 00:01:25.700
# Lord Gwyn: "A'ight."
#
# 00:01:25.900 --> 00:01:28.000
# Witch of Izalith: "Shit! The fire's dyin' out!"
#
# 00:01:28.000 --> 00:01:30.000
# Witch of Izalith: "Hey, I've got a crazy idea!"
#
# 00:01:30.500 --> 00:01:31.900
# Lord Gwyn: "...Go on..."
#
# 00:01:32.300 --> 00:01:34.900
# Witch of Izalith: "We got these Souls from the First Flame, right?"
#
# 00:01:35.000 --> 00:01:37.600
# Witch of Izalith: "I'll use MY soul to make another Fire!"
#
# 00:01:37.600 --> 00:01:38.600
# Lord Gwyn: "I don't think that's - !"
#
# 00:01:41.400 --> 00:01:43.800
# Bed of Chaos: "Look at all my cute demon babies!"
#
# 00:01:43.800 --> 00:01:44.700
# Lord Gwyn: "God damn it."
#
# 00:01:44.700 --> 00:01:47.000
# Lord Gwyn: "You stay here. We'll take care of this!"
#
# 00:01:47.000 --> 00:01:48.500
# Lord Gwyn: "Charge!"
#
# 00:01:49.200 --> 00:01:51.000
# Lord Gwyn: "Oh god! Retreat! Retreat!"
#
# 00:01:51.300 --> 00:01:52.700
# Lord Gwyn: "Ugh. Fuck it!"
#
# 00:01:52.900 --> 00:01:54.700
# Lord Gwyn: "I'll just light myself on fire!"
#
# 00:01:54.700 --> 00:01:55.700
# Solaire: "Daaaaad..."
#
# 00:01:55.700 --> 00:01:57.100
# Nerd 1: "Hey! That is NOT canon!"
#
# 00:01:57.100 --> 00:01:58.600
# Nerd 2: "Shut uppp! It's fan canon!"
#
# 00:01:58.600 --> 00:02:01.000
# Solaire: "I... kind of... lost the Annals of History."
#
# 00:02:01.000 --> 00:02:02.700
# Lord Gwyn: "Well, son, I'm disappointed...
#
# 00:02:02.700 --> 00:02:04.000
# Lord Gwyn: "...but I still love you despite - "
#
# 00:02:04.000 --> 00:02:05.000
# Solaire: "Anddd..."
#
# 00:02:05.000 --> 00:02:06.500
# Solaire: "...your Van Halen mix tape."
#
# 00:02:07.000 --> 00:02:08.800
# Lord Gwyn: "Get OUTTTTT."
#
# 00:02:09.800 --> 00:02:12.900
# Lord Gwyn: "Gwyndolin, take care of Anor Londo while Daddy is consumed by the First Flame!"
#
# 00:02:13.200 --> 00:02:14.500
# Gwyndolin: "I'm actually a boy!"
#
# 00:02:14.500 --> 00:02:15.800
# Lord Gwyn: "Not NOW, SWEETIE."
#
# 00:02:16.000 --> 00:02:17.000
# Havel: "Sir, what about Seath?"
#
# 00:02:17.200 --> 00:02:18.000
# Lord Gwyn: "What about him?"
#
# 00:02:18.500 --> 00:02:19.500
# [ Perverse Noises ]
#
# 00:02:20.000 --> 00:02:24.000
# [ Van Halen - Why Can't This Be Love? ]
#
# 00:02:29.800 --> 00:02:33.000
# [ Perverse Noises Intensify ]
#
# 00:02:33.000 --> 00:02:34.000
# [ Vials Clicking, Magical Bullshit ]
#
# 00:02:34.500 --> 00:02:36.500
# [ Priscilla Cooing ]
#
# 00:02:36.500 --> 00:02:38.000
# Havel: "We can't get the stains out, either."
#
# 00:02:38.200 --> 00:02:39.600
# Lord Gwyn: "You will never speak of this to anyone."
#
# 00:02:40.000 --> 00:02:40.900
# [ Prison Cell Closes ]
#
# 00:02:41.400 --> 00:02:42.900
# Lord Gwyn: "Sunlight 4 Life!"
#
# 00:02:43.500 --> 00:02:46.300
# [ Horrible Screaming ]
#
# 00:02:47.000 --> 00:02:48.400
# Frampt: "This shit is fucked!"
#
# 00:02:48.400 --> 00:02:51.000
# Frampt: "I'll go find some more dudes to set on fire."
#
# 00:02:51.000 --> 00:02:53.100
# Kaathe: "That's dumb. You're dumb!"
#
# 00:02:53.100 --> 00:02:55.900
# Kaathe: "I'll go get this Dark Party started right!"
#
# 00:02:56.200 --> 00:02:57.000
# [ Peaceful Nature Sounds ]
#
# 00:02:57.200 --> 00:02:58.900
# Kaathe: "You know what you guys need?"
#
# 00:03:00.200 --> 00:03:03.900
# Kaathe: "To feed off the humanity of Manus's corpse -
# the Primeval Man!"
#
# 00:03:05.400 --> 00:03:06.900
# [ Chaotic Slaughter Noises ]
#
# 00:03:08.000 --> 00:03:09.300
# [ Peaceful Nature Sounds ]
#
# 00:03:09.700 --> 00:03:11.200
# Kaathe: "You know what you guys need?"
#
# 00:03:12.700 --> 00:03:14.800
# Kaathe: "To feed off the humanity of other humans!"
#
# 00:03:16.500 --> 00:03:17.900
# [ Chaotic Slaughter Noises ]
#
# 00:03:19.500 --> 00:03:23.000
# Kaathe: "Oh, Knight Artorias! How's Ciaran doing?"
#
# 00:03:23.000 --> 00:03:24.000
# Artorias: "Still hot."
#
# 00:03:25.100 --> 00:03:27.000
# Artorias: "Check out this puppy."
#
# 00:03:27.000 --> 00:03:28.000
# [ Puppy Sif Barks ]
#
# 00:03:28.000 --> 00:03:29.000
# Kaathe: "Amazing!"
#
# 00:03:29.000 --> 00:03:30.000
# Artorias: "Hey, so..."
#
# 00:03:30.000 --> 00:03:32.000
# Artorias: "Abyss is kind of running wild."
#
# 00:03:32.300 --> 00:03:33.900
# Artorias: "Wouldn't know anything about that, would y - "
#
# 00:03:33.900 --> 00:03:34.900
# Kaathe: "NO. WHY!?"
#
# 00:03:35.200 --> 00:03:39.600
# Artorias: "Let's make a suspicious covenant,
# so I can get all up in the Abyss' asshole!"
#
# 00:03:39.600 --> 00:03:41.900
# Kaathe: "There's nothing about that sentence I don't love."
#
# 00:03:42.600 --> 00:03:45.200
# Kaathe: "Now! Back to being ambiguously evil..."
#
# 00:03:45.800 --> 00:03:49.500
# Artorias: "Yyyyup. Looks like there's a clog further up the pipe, near Oolacile."
#
# 00:03:50.200 --> 00:03:51.700
# Artorias: "If I don't call back by Thursday..."
#
# 00:03:51.700 --> 00:03:54.700
# Artorias: "...just go ahead and do what need'st be done."
#
# 00:03:55.300 --> 00:03:55.900
# Artorias: "...Thou'st!"
#
# 00:03:55.900 --> 00:03:57.900
# Ingward: "Oh yes! Of course, of course!"
#
# 00:03:58.900 --> 00:03:59.900
# Ingward: "Finally, he's gone..."
#
# 00:04:00.500 --> 00:04:03.300
# Ingward: "New Londo Waterpark opens today!"
#
# 00:04:04.000 --> 00:04:06.000
# [ Torrent of Water Washes Clean the Sins of Man ]
#
# 00:04:06.600 --> 00:04:07.700
# Artorias: "Bad news, Puppy Sif!"
#
# 00:04:07.900 --> 00:04:10.400
# Artorias: "My arm's broke as hell for... some reason."
#
# 00:04:10.700 --> 00:04:12.700
# Humanity: "You came to the wrong neighborhood, motherfucker!"
#
# 00:04:12.700 --> 00:04:13.300
# Artorias: "HEY!"
#
# 00:04:13.400 --> 00:04:14.600
# Artorias: "That is RACIST!"
#
# 00:04:14.800 --> 00:04:15.600
# Humanity: "I'm sorry..."
#
# 00:04:16.000 --> 00:04:18.700
# Artorias: "Take my weird ass shield, Puppy Sif!"
#
# 00:04:18.700 --> 00:04:21.500
# Artorias: "It'll protect you from... urban violence!"
#
# 00:04:22.000 --> 00:04:22.500
# [ Puppy Sif Barking Continues, Unabated by Urban Violence ]
#
# 00:04:22.500 --> 00:04:23.500
# Artorias: "Wish me luck!"
#
# 00:04:23.500 --> 00:04:27.200
# Artorias: "I'm off to fill Manus' man cavern with my estus flask!"
#
# 00:04:28.000 --> 00:04:29.300
# [ Fog Gate Noise ]
#
# 00:04:29.700 --> 00:04:31.600
# Artorias: "All right, Manus! It's time to - "
#
# 00:04:31.600 --> 00:04:31.800
# [ Grabbing ]
#
# 00:04:31.900 --> 00:04:33.300
# Artorias: "Oh! Oh no, oh god!"
#
# 00:04:33.300 --> 00:04:36.000
# Artorias: "He's putting his Abyss in my Catacombs!"
#
# 00:04:37.200 --> 00:04:40.200
# Generic Asshole 1: "Ugh. These undead are becoming tiresome."
#
# 00:04:40.200 --> 00:04:42.900
# Generic Asshole 2: "Maybe we can find a solution in Lordran?"
#
# 00:04:42.900 --> 00:04:45.900
# Generic Asshole 1: "Just send them all to that decaying Asylum, in the meantime."
#
# 00:04:46.400 --> 00:04:47.100
# Undead Warrior: "We're not all bad!"
#
# 00:04:47.200 --> 00:04:50.700
# Undead Warrior: "As long as we stay motivated for life,
# we can keep our humanity!
#
# 00:04:50.900 --> 00:04:53.400
# Peon: "Sir, the latest patch maladapted your stat alignment!"
#
# 00:04:53.400 --> 00:04:54.300
# [ Hollowing ]
#
# 00:04:54.300 --> 00:04:56.000
# Peon: "Ahh! So easily!"
#
# 00:04:57.900 --> 00:05:04.300
# [ Pooting Noises ]
#
# 00:05:04.300 --> 00:05:04.700
# [ Let the Body Hit the Floor ]
#
# 00:05:04.800 --> 00:05:05.700
# Player: "Ah, dead body!"
#
# 00:05:05.900 --> 00:05:06.700
# Oscar: "Psst!"
#
# 00:05:06.900 --> 00:05:10.800
# Oscar: "I'm letting all the undead out of their cells,
# to fulfill an ancient prophecy."
#
# 00:05:11.000 --> 00:05:12.400
# Oscar: "There's a key on that corpse."
#
# 00:05:12.500 --> 00:05:14.700
# Player: "Why did you just throw me the key, asshole?"
#
# 00:05:16.000 --> 00:05:16.800
# Player: "Eugh."
#
# 00:05:16.900 --> 00:05:19.300
# Oscar: "Perhaps you should find your own answers."
#
# 00:05:19.300 --> 00:05:19.700
# [ BOSS BATTLE ]
#
# 00:05:19.700 --> 00:05:20.600
# Oscar: "DEMON ON THE ROOF!"
#
# 00:05:20.600 --> 00:05:21.600
# [ DEMON HAMMER ]
#
# 00:05:22.200 --> 00:05:24.500
# Narrator: "All of history has led up to this moment!"
#
# 00:05:24.500 --> 00:05:30.200
# Narrator: "Will you rekindle the Age of Fire, and bring prosperity
# to the world for another thousand years?"
#
# 00:05:30.200 --> 00:05:35.000
# Narrator: "Or fulfill your ancestor's wish,
# and become the Lord of the Dark Soul?
#
# 00:05:38.000 --> 00:05:42.000
# [ BUHHHHHH ]
#
# 00:05:46.200 --> 00:05:48.500
# Eli: "I can't wait for the sequel."
#
# 00:05:57.000 --> 00:06:00.200
# Eli: "Thank you for watching the cartoon. I nearly died making it."
#
# 00:06:00.200 --> 00:06:01.200
# Eli: "Again."
#
# 00:06:01.200 --> 00:06:08.500
# Eli: "Feel free to explore the body of my horrifying Youtube work, while I prepare for my inevitable death by stroke."
#
# 00:06:08.500 --> 00:06:10.500
# Eli: "Praise the sun!"
# The video transcript presents a humorous and exaggerated retelling of the lore of "Dark Souls," featuring characters such as dragons, Lord Gwyn, and Seath. It introduces themes of humor through interactions among dragons, where they boast about their existence and mock Seath for his lack of scales and legs. The narrative unfolds with Lord Gwyn discussing the consequences of using souls from the First Flame and encounters with the Witch of Izalith, resulting in chaotic events. Various characters express their frustrations and ridiculous situations while referencing in-game events and mechanics, all wrapped in comedic dialogue. The narrator prompts players to reflect on their choices surrounding the game's lore. The video ends with creator Eli expressing his struggles in making the cartoon and inviting viewers to explore his other works.

# %%
# for articles:
article_text = extract_article("https://medium.com/@deshwaljaivardhan/the-algorithm-said-no-and-youll-never-know-why-0dd2c7862259")
print(summarize_text(article_text))
# Out:
# AI bias refers to the unfair or prejudiced decisions made by artificial intelligence systems due to skewed data or flawed algorithms. This bias can significantly impact various aspects of life:
#
# 1. **Resume Screening & AI Hiring Tools**: These tools can unintentionally downgrade candidates based on biased historical hiring practices, such as women’s colleges or foreign names, leading to unfair rejections without feedback.
#
# 2. **CIBIL Scores & Creditworthiness**: Credit scoring algorithms may use biased data, like zip codes, resulting in disadvantaged access to credit for minorities or low-income groups. Consequently, individuals could be denied loans based on assumptions tied to their location or demographic.
#
# 3. **Healthcare Algorithms**: AI in healthcare has been shown to predict lower care needs for Black patients compared to equally sick white patients due to historical data biases, leading to unequal healthcare access.
#
# 4. **Facial Recognition in Policing**: Facial recognition technology often performs poorly on darker skin tones, particularly for women, leading to innocent individuals being flagged and perpetuating existing inequalities in surveillance.
#
# In summary, AI bias has real-world implications, affecting hiring, credit access, healthcare, and policing, and can reinforce systemic inequalities.
