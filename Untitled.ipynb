# %%
# Out:
# API key found and looks good so far!
#
# === Test Case 1 ===
# Query: Hi, I need to check the status of my order ORD-12345
# Query Type: order_inquiry
# Sentiment: neutral
# Priority: medium
# Order ID: ORD-12345
# Requires Escalation: False
# Resolution Steps: []
# Final Response: Subject: Your Order Status Update - ORD-12345
#
# Dear John Doe,
#
# Thank you for reaching out to us regarding the status of your order, ORD-12345. I'm happy to provide you with the latest information.
#
# Your order was shipped on January 15, 2024, and is currently in transit. The tracking number for your shipment is TRK-789456123. As of now, your package is at the Distribution Center in Chicago and is expected to be delivered to your shipping address at 123 Main St, City, State 12345 by January 20, 2024.
#
# Here’s a brief overview of your order details:
# - **Items Ordered:**
#   - Wireless Headphones (1) - $99.99
#   - Phone Case (2) - $39.98
# - **Total Amount:** $139.97
# ...
